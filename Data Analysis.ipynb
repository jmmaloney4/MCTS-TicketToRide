6,brrm,3,2732.0745829343796
7,brrm,3,2594.225124001503
8,brrm,2,2641.8167510032654
9,brrm,2,2615.9697350263596
10,brrm,3,2786.7354720830917
11,brrm,3,2598.3977069854736
12,brrm,3,2741.4392269849777
13,brrm,2,2648.0986169576645
14,brrm,1,2559.44939994812
15,brrm,3,2469.8579120635986
16,brrm,3,2677.4166779518127
17,brrm,3,2799.528741955757
18,brrm,3,2535.594004034996
19,brrm,3,2628.4059170484543
"""))

# %%
df = pd.concat([brrm03['WINNER'], brrm08['WINNER'], brrm10['WINNER'], brrm11['WINNER'], brrm12['WINNER'], brrm25['WINNER']], axis=1, keys=['brrm03', 'brrm08', 'brrm10', 'brrm11', 'brrm12', 'brrm25'])
# plt.bar(df.)

# %%
winpct = df.apply(lambda x: x.value_counts(normalize=True))

# %%
winpct
# Out:
#    brrm03  brrm08  brrm10  brrm11  brrm12  brrm25
# 0    0.10    0.15    0.05    0.15    0.05     NaN
# 1    0.25    0.15    0.10    0.20    0.20    0.15
# 2    0.25    0.10    0.05    0.15    0.15    0.15
# 3    0.40    0.60    0.80    0.50    0.60    0.70

# %%
r2 = pd.read_csv("results/rvr2.csv")
r3 = pd.read_csv("results/rvr3.csv")
r4 = pd.read_csv("results/rvr4.csv")
r5 = pd.read_csv("results/rvr5.csv")
r6 = pd.read_csv("results/rvr6.csv")
r7 = pd.read_csv("results/rvr7.csv")

rvr = pd.concat([r2['WINNER'], r3['WINNER'], r4['WINNER'], r5['WINNER'], r6['WINNER'], r7['WINNER']], axis=1, keys=['two', 'three', 'four', 'five', 'six', 'seven'])
rvr = rvr.apply(lambda x: x.value_counts(normalize=True)).transpose()
rvr
# Out:
#               0         1         2         3         4         5         6
# two    0.560333  0.439667       NaN       NaN       NaN       NaN       NaN
# three  0.373333  0.350333  0.276333       NaN       NaN       NaN       NaN
# four   0.280667  0.252667  0.243333  0.223333       NaN       NaN       NaN
# five   0.235000  0.223333  0.187000  0.191667  0.163000       NaN       NaN
# six    0.187333  0.178333  0.170333  0.172000  0.148333  0.143667       NaN
# seven  0.156333  0.155000  0.159000  0.139333  0.124667  0.135000  0.130667

# %%
b2 = pd.read_csv("results/bvb2.csv")
b3 = pd.read_csv("results/bvb3.csv")
b4 = pd.read_csv("results/bvb4.csv")
b5 = pd.read_csv("results/bvb5.csv")
b6 = pd.read_csv("results/bvb6.csv")
b7 = pd.read_csv("results/bvb7.csv")

bvb = pd.concat([b2['WINNER'], b3['WINNER'], b4['WINNER'], b5['WINNER'], b6['WINNER'], b7['WINNER']], axis=1, keys=['two', 'three', 'four', 'five', 'six', 'seven'])
bvb = bvb.apply(lambda x: x.value_counts(normalize=True)).transpose()
bvb.plot.bar()

# %%
m2 = pd.read_csv("results/mvm2.csv")
m3 = pd.read_csv("results/mvm3.csv")

mvm = pd.concat([m2['WINNER'], m3['WINNER']], axis=1, keys=['two', 'three'])
mvm = mvm.apply(lambda x: x.value_counts(normalize=True)).transpose()
mvm
# Out:
#           0    1     2
# two    0.80  0.2   NaN
# three  0.55  0.3  0.15

# %%
m20k = pd.read_csv("results/20k.csv")

m20k = pd.concat([m20k['WINNER']], axis=1, keys=['20k'])
m20k = m20k.apply(lambda x: x.value_counts(normalize=True)).transpose()
m20k
# Out:
#        3     1     0
# 20k  0.8  0.15  0.05

# %%
m148 = pd.read_csv("results/148.csv")
m814 = pd.read_csv("results/814.csv")

m814 = pd.concat([m148['WINNER'], m814['WINNER']], axis=1, keys=['m148', 'm814'])
m814 = m814.apply(lambda x: x.value_counts(normalize=True)).transpose()
m814
# Out:
#         0    1    2
# m148  0.3  0.3  0.4
# m814  0.5  0.4  0.1
